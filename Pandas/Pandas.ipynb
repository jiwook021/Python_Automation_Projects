# %%
import pandas as pd
import numpy as np

# df = pd.read_csv("iris.csv")
# df.head()

# #print(df.head(10))
# #print(df.tail(10))

# filename = "lsg_stats.xlsx"
# xls = pd.ExcelFile(filename)
# xls.sheet_names

 
# for sheet in xls.sheet_names:
#     dfs = pd.read_excel(filename, sheet_name=sheet)
#     print(dfs.head())


df = pd.read_excel("lsg_stats.xlsx", sheet_name="2021q3")

# print(df2)

#  for column in df2.columns:
#     print(column)

new_cols = list(df.columns)
new_cols[0] = "Suburb"
new_cols[1] = "City"
new_df = df[new_cols]
# print(new_df.head())

df["Index"] = [i for i in range(len(df))]
df["Country"] = "USA"

print(df.head())
# Out:
#              City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 0        ADELAIDE        ADELAIDE            3.0        671000.0
# 1        ADELAIDE  NORTH ADELAIDE            8.0       1025000.0
# 2  ADELAIDE HILLS         ALDGATE           11.0        730000.0
# 3  ADELAIDE HILLS          ASHTON            NaN             NaN
# 4  ADELAIDE HILLS    BASKET RANGE            NaN             NaN
#
#    Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country
# 0            5.0       1012500.0       0.508942      0     USA
# 1            9.0       1250000.0       0.219512      1     USA
# 2           15.0        875000.0       0.198630      2     USA
# 3            1.0        765000.0            NaN      3     USA
# 4            NaN             NaN            NaN      4     USA

# %%
df["Sales Change"] = df["Sales 3Q 2021"] - df["Sales 3Q 2020"]
print(df)
# Out:
#                City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 0          ADELAIDE        ADELAIDE            3.0        671000.0
# 1          ADELAIDE  NORTH ADELAIDE            8.0       1025000.0
# 2    ADELAIDE HILLS         ALDGATE           11.0        730000.0
# 3    ADELAIDE HILLS          ASHTON            NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE            NaN             NaN
# ..              ...             ...            ...             ...
# 474    WEST TORRENS       THEBARTON            1.0        890000.0
# 475    WEST TORRENS    TORRENSVILLE           10.0        617500.0
# 476    WEST TORRENS       UNDERDALE            4.0        650000.0
# 477    WEST TORRENS      WEST BEACH           16.0        805000.0
# 478    WEST TORRENS   WEST RICHMOND            5.0        475500.0
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# 0              5.0       1012500.0       0.508942      0     USA           2.0
# ...

# %%
df["Sales 3Q 2021"].apply(np.log10)
# Out:
# 0      0.698970
# 1      0.954243
# 2      1.176091
# 3      0.000000
# 4           NaN
#          ...
# 474    0.778151
# 475    1.176091
# 476    1.041393
# 477    1.230449
# 478    0.602060
# Name: Sales 3Q 2021, Length: 479, dtype: float64

# %%
print(df)
# Out:
#                City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 0          ADELAIDE        ADELAIDE            3.0        671000.0
# 1          ADELAIDE  NORTH ADELAIDE            8.0       1025000.0
# 2    ADELAIDE HILLS         ALDGATE           11.0        730000.0
# 3    ADELAIDE HILLS          ASHTON            NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE            NaN             NaN
# ..              ...             ...            ...             ...
# 474    WEST TORRENS       THEBARTON            1.0        890000.0
# 475    WEST TORRENS    TORRENSVILLE           10.0        617500.0
# 476    WEST TORRENS       UNDERDALE            4.0        650000.0
# 477    WEST TORRENS      WEST BEACH           16.0        805000.0
# 478    WEST TORRENS   WEST RICHMOND            5.0        475500.0
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# 0              5.0       1012500.0       0.508942      0     USA           2.0
# ...

# %%
for row in df.itertuples():
    print(row)
# Out:
# Pandas(Index=0, City='ADELAIDE', Suburb='ADELAIDE', _3=3.0, _4=671000.0, _5=5.0, _6=1012500.0, _7=0.5089418777943369, _8=0, Country='USA', _10=2.0)
# Pandas(Index=1, City='ADELAIDE', Suburb='NORTH ADELAIDE', _3=8.0, _4=1025000.0, _5=9.0, _6=1250000.0, _7=0.21951219512195122, _8=1, Country='USA', _10=1.0)
# Pandas(Index=2, City='ADELAIDE HILLS', Suburb='ALDGATE', _3=11.0, _4=730000.0, _5=15.0, _6=875000.0, _7=0.19863013698630136, _8=2, Country='USA', _10=4.0)
# Pandas(Index=3, City='ADELAIDE HILLS', Suburb='ASHTON', _3=nan, _4=nan, _5=1.0, _6=765000.0, _7=nan, _8=3, Country='USA', _10=nan)
# Pandas(Index=4, City='ADELAIDE HILLS', Suburb='BASKET RANGE', _3=nan, _4=nan, _5=nan, _6=nan, _7=nan, _8=4, Country='USA', _10=nan)
# Pandas(Index=5, City='ADELAIDE HILLS', Suburb='BELAIR', _3=16.0, _4=665000.0, _5=18.0, _6=815000.0, _7=0.22556390977443608, _8=5, Country='USA', _10=2.0)
# ...

# %%
sorted_df = df.sort_values("Sales 3Q 2020")
sorted_df
# Out:
#                City            Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 241     ONKAPARINGA          IRONBANK            1.0        937000.0
# 440           UNLEY           KESWICK            1.0        650000.0
# 441           UNLEY        KINGS PARK            1.0       1375000.0
# 134    HOLDFAST BAY     KINGSTON PARK            1.0        630000.0
# 434           UNLEY      EVERARD PARK            1.0        925000.0
# ..              ...               ...            ...             ...
# 412  TEA TREE GULLY       GOULD CREEK            NaN             NaN
# 431  TEA TREE GULLY       YATALA VALE            NaN             NaN
# 453    WEST TORRENS  ADELAIDE AIRPORT            NaN             NaN
# 463    WEST TORRENS  KESWICK TERMINAL            NaN             NaN
# 468    WEST TORRENS    MILE END SOUTH            NaN             NaN
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# ...

# %%
sorted_df = df.sort_values("Sales 3Q 2020", ascending=False)
sorted_df
# Out:
#                       City            Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 248            ONKAPARINGA     MORPHETT VALE           70.0        325000.0
# 223            ONKAPARINGA     ALDINGA BEACH           63.0        395000.0
# 393              SALISBURY         PARALOWIE           57.0        340000.0
# 372               PROSPECT          PROSPECT           53.0        690000.0
# 353  PORT ADELAIDE ENFIELD          PROSPECT           53.0        690000.0
# ..                     ...               ...            ...             ...
# 412         TEA TREE GULLY       GOULD CREEK            NaN             NaN
# 431         TEA TREE GULLY       YATALA VALE            NaN             NaN
# 453           WEST TORRENS  ADELAIDE AIRPORT            NaN             NaN
# 463           WEST TORRENS  KESWICK TERMINAL            NaN             NaN
# 468           WEST TORRENS    MILE END SOUTH            NaN             NaN
#
# ...

# %%
df.groupby("City").mean()
# Out:
#                               Sales 3Q 2020  Median 3Q 2020  Sales 3Q 2021  \
# City
# ADELAIDE                           5.500000    8.480000e+05       7.000000
# ADELAIDE HILLS                     6.277778    7.122222e+05       8.333333
# BURNSIDE                           6.440000    1.053250e+06       6.680000
# CAMPBELLTOWN                      22.250000    6.004062e+05      28.000000
# CHARLES STURT                      9.657895    6.256618e+05      10.435897
# GAWLER                             8.100000    3.323800e+05      13.300000
# HOLDFAST BAY                       6.909091    8.392727e+05       7.000000
# MARION                            11.538462    5.313269e+05      12.407407
# MITCHAM                            6.724138    7.769598e+05      10.285714
# NORWOOD PAYNEHAM & ST PETERS       5.000000    1.000339e+06       4.950000
# ONKAPARINGA                       17.051282    4.594183e+05      19.700000
# ...

# %%
df
# Out:
#                City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 0          ADELAIDE        ADELAIDE            3.0        671000.0
# 1          ADELAIDE  NORTH ADELAIDE            8.0       1025000.0
# 2    ADELAIDE HILLS         ALDGATE           11.0        730000.0
# 3    ADELAIDE HILLS          ASHTON            NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE            NaN             NaN
# ..              ...             ...            ...             ...
# 474    WEST TORRENS       THEBARTON            1.0        890000.0
# 475    WEST TORRENS    TORRENSVILLE           10.0        617500.0
# 476    WEST TORRENS       UNDERDALE            4.0        650000.0
# 477    WEST TORRENS      WEST BEACH           16.0        805000.0
# 478    WEST TORRENS   WEST RICHMOND            5.0        475500.0
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# 0              5.0       1012500.0       0.508942      0     USA           2.0
# ...

# %%
df.groupby("City").size()
# Out:
# City
# ADELAIDE                         2
# ADELAIDE HILLS                  35
# BURNSIDE                        29
# CAMPBELLTOWN                     8
# CHARLES STURT                   40
# GAWLER                          14
# HOLDFAST BAY                    12
# MARION                          28
# MITCHAM                         32
# NORWOOD PAYNEHAM & ST PETERS    21
# ONKAPARINGA                     53
# PLAYFORD                        38
# PORT ADELAIDE ENFIELD           54
# PROSPECT                         9
# SALISBURY                       32
# TEA TREE GULLY                  25
# UNLEY                           17
# WALKERVILLE                      4
# WEST TORRENS                    26
# dtype: int64

# %%
df.groupby("City").median()
# Out:
#                               Sales 3Q 2020  Median 3Q 2020  Sales 3Q 2021  \
# City
# ADELAIDE                                5.5        848000.0            7.0
# ADELAIDE HILLS                          3.0        685500.0            4.0
# BURNSIDE                                4.0        953500.0            5.0
# CAMPBELLTOWN                           23.0        583750.0           30.5
# CHARLES STURT                           7.5        567500.0            7.0
# GAWLER                                  8.0        336750.0           13.0
# HOLDFAST BAY                            7.0        770000.0            6.0
# MARION                                 10.0        516250.0           11.0
# MITCHAM                                 6.0        712500.0           10.0
# NORWOOD PAYNEHAM & ST PETERS            4.5        812500.0            4.0
# ONKAPARINGA                            11.0        422500.0           13.0
# ...

# %%
df
# Out:
#                City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 0          ADELAIDE        ADELAIDE            3.0        671000.0
# 1          ADELAIDE  NORTH ADELAIDE            8.0       1025000.0
# 2    ADELAIDE HILLS         ALDGATE           11.0        730000.0
# 3    ADELAIDE HILLS          ASHTON            NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE            NaN             NaN
# ..              ...             ...            ...             ...
# 474    WEST TORRENS       THEBARTON            1.0        890000.0
# 475    WEST TORRENS    TORRENSVILLE           10.0        617500.0
# 476    WEST TORRENS       UNDERDALE            4.0        650000.0
# 477    WEST TORRENS      WEST BEACH           16.0        805000.0
# 478    WEST TORRENS   WEST RICHMOND            5.0        475500.0
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# 0              5.0       1012500.0       0.508942      0     USA           2.0
# ...

# %%
df.groupby("City").min()
# Out:
#                                         Suburb  Sales 3Q 2020  Median 3Q 2020  \
# City
# ADELAIDE                              ADELAIDE            3.0        671000.0
# ADELAIDE HILLS                         ALDGATE            1.0        412000.0
# BURNSIDE                               AULDANA            2.0        670000.0
# CAMPBELLTOWN                        ATHELSTONE            6.0        549500.0
# CHARLES STURT                      ALBERT PARK            2.0        395000.0
# GAWLER                               BIBARINGA            1.0        217500.0
# HOLDFAST BAY                          BRIGHTON            1.0        574500.0
# MARION                              ASCOT PARK            2.0        411000.0
# MITCHAM                           BEDFORD PARK            1.0        487000.0
# NORWOOD PAYNEHAM & ST PETERS      COLLEGE PARK            1.0        655000.0
# ONKAPARINGA                     ABERFOYLE PARK            1.0        258025.0
# ...

# %%
df.groupby("City").max()
# Out:
#                                          Suburb  Sales 3Q 2020  \
# City
# ADELAIDE                         NORTH ADELAIDE            8.0
# ADELAIDE HILLS                        WOODFORDE           24.0
# BURNSIDE                            WATTLE PARK           38.0
# CAMPBELLTOWN                           TRANMERE           38.0
# CHARLES STURT                    WOODVILLE WEST           28.0
# GAWLER                                WILLASTON           18.0
# HOLDFAST BAY                     SOUTH BRIGHTON           18.0
# MARION                                WARRADALE           51.0
# MITCHAM                         WESTBOURNE PARK           16.0
# NORWOOD PAYNEHAM & ST PETERS    TRINITY GARDENS           16.0
# ONKAPARINGA                           WOODCROFT           70.0
# PLAYFORD                             YATTALUNGA           41.0
# PORT ADELAIDE ENFIELD         WOODVILLE GARDENS           53.0
# PROSPECT                              THORNGATE           53.0
# ...

# %%
df.groupby("City").sum()
# Out:
#                               Sales 3Q 2020  Median 3Q 2020  Sales 3Q 2021  \
# City
# ADELAIDE                               11.0       1696000.0           14.0
# ADELAIDE HILLS                        113.0      12820000.0          125.0
# BURNSIDE                              161.0      26331250.0          167.0
# CAMPBELLTOWN                          178.0       4803250.0          224.0
# CHARLES STURT                         367.0      23775150.0          407.0
# GAWLER                                 81.0       3323800.0          133.0
# HOLDFAST BAY                           76.0       9232000.0           77.0
# MARION                                300.0      13814500.0          335.0
# MITCHAM                               195.0      22531834.0          288.0
# NORWOOD PAYNEHAM & ST PETERS           90.0      18006094.0           99.0
# ONKAPARINGA                           665.0      17917315.5          788.0
# ...

# %%
df.groupby("City").prod()
# Out:
#                               Sales 3Q 2020  Median 3Q 2020  Sales 3Q 2021  \
# City
# ADELAIDE                       2.400000e+01    6.877750e+11   4.500000e+01
# ADELAIDE HILLS                 1.302884e+10   1.358584e+105   2.547418e+10
# BURNSIDE                       8.198409e+16   1.591854e+150   2.362793e+17
# CAMPBELLTOWN                   2.037620e+10    1.644127e+46   2.069671e+11
# CHARLES STURT                  1.586168e+33   4.395998e+219   3.560685e+34
# GAWLER                         2.830464e+07    1.468140e+55   7.448760e+08
# HOLDFAST BAY                   1.481760e+08    9.939479e+64   1.729728e+08
# MARION                         7.533690e+24   5.777719e+148   5.766719e+27
# MITCHAM                        4.140396e+21   2.323314e+170   1.873796e+26
# NORWOOD PAYNEHAM & ST PETERS   7.166362e+10   1.924369e+107   6.333466e+10
# ONKAPARINGA                    3.121114e+41   1.291179e+220   1.379729e+45
# ...

# %%
df.groupby("City").std()
# Out:
#                               Sales 3Q 2020  Median 3Q 2020  Sales 3Q 2021  \
# City
# ADELAIDE                           3.535534   250315.800540       2.828427
# ADELAIDE HILLS                     6.951983   169599.720989      10.654755
# BURNSIDE                           7.223111   314073.521780       6.196235
# CAMPBELLTOWN                      10.402610    52848.154702      10.690450
# CHARLES STURT                      6.703272   192646.661728       8.506329
# GAWLER                             6.063552    49123.988256      10.781156
# HOLDFAST BAY                       4.614207   238566.800251       4.516636
# MARION                            10.016909    72470.365296       7.757177
# MITCHAM                            4.007997   216585.545412       5.394491
# NORWOOD PAYNEHAM & ST PETERS       3.629941   568503.178411       4.536112
# ONKAPARINGA                       16.372231   143765.965173      18.035862
# ...

# %%
df.groupby("City").var()
# Out:
#                               Sales 3Q 2020  Median 3Q 2020  Sales 3Q 2021  \
# City
# ADELAIDE                          12.500000    6.265800e+10       8.000000
# ADELAIDE HILLS                    48.330065    2.876407e+10     113.523810
# BURNSIDE                          52.173333    9.864218e+10      38.393333
# CAMPBELLTOWN                     108.214286    2.792927e+09     114.285714
# CHARLES STURT                     44.933855    3.711274e+10      72.357625
# GAWLER                            36.766667    2.413166e+09     116.233333
# HOLDFAST BAY                      21.290909    5.691412e+10      20.400000
# MARION                           100.338462    5.251954e+09      60.173789
# MITCHAM                           16.064039    4.690930e+10      29.100529
# NORWOOD PAYNEHAM & ST PETERS      13.176471    3.231959e+11      20.576316
# ONKAPARINGA                      268.049933    2.066865e+10     325.292308
# ...

# %%
df.groupby("City").quantile()
# Out:
# C:\Users\jiwoo\AppData\Local\Temp/ipykernel_29360/2700628712.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.quantile is deprecated. In a future version, a TypeError will be raised. Before calling .quantile, select only columns which should be valid for the function.
#   df.groupby("City").quantile()
#                               Sales 3Q 2020  Median 3Q 2020  Sales 3Q 2021  \
# City
# ADELAIDE                                5.5        848000.0            7.0
# ADELAIDE HILLS                          3.0        685500.0            4.0
# BURNSIDE                                4.0        953500.0            5.0
# CAMPBELLTOWN                           23.0        583750.0           30.5
# CHARLES STURT                           7.5        567500.0            7.0
# GAWLER                                  8.0        336750.0           13.0
# HOLDFAST BAY                            7.0        770000.0            6.0
# ...

# %%
df.groupby("City").first()
# Out:
#                                         Suburb  Sales 3Q 2020  Median 3Q 2020  \
# City
# ADELAIDE                              ADELAIDE            3.0        671000.0
# ADELAIDE HILLS                         ALDGATE           11.0        730000.0
# BURNSIDE                               AULDANA            3.0       1060000.0
# CAMPBELLTOWN                        ATHELSTONE           31.0        550000.0
# CHARLES STURT                      ALBERT PARK            3.0        448500.0
# GAWLER                               BIBARINGA            6.0        358300.0
# HOLDFAST BAY                          BRIGHTON            7.0        574500.0
# MARION                              ASCOT PARK           10.0        512500.0
# MITCHAM                           BEDFORD PARK            2.0        497500.0
# NORWOOD PAYNEHAM & ST PETERS      COLLEGE PARK            2.0       2990000.0
# ONKAPARINGA                     ABERFOYLE PARK           40.0        458000.0
# ...

# %%
df.groupby("City").describe()
# Out:
#                              Sales 3Q 2020                                    \
#                                      count       mean        std  min    25%
# City
# ADELAIDE                               2.0   5.500000   3.535534  3.0   4.25
# ADELAIDE HILLS                        18.0   6.277778   6.951983  1.0   2.00
# BURNSIDE                              25.0   6.440000   7.223111  2.0   3.00
# CAMPBELLTOWN                           8.0  22.250000  10.402610  6.0  18.25
# CHARLES STURT                         38.0   9.657895   6.703272  2.0   4.00
# GAWLER                                10.0   8.100000   6.063552  1.0   2.25
# HOLDFAST BAY                          11.0   6.909091   4.614207  1.0   4.00
# MARION                                26.0  11.538462  10.016909  2.0   6.25
# MITCHAM                               29.0   6.724138   4.007997  1.0   4.00
# NORWOOD PAYNEHAM & ST PETERS          18.0   5.000000   3.629941  1.0   2.25
# ...

# %%
df[df["Sales 3Q 2020"] > 8]
# Out:
#                City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 2    ADELAIDE HILLS         ALDGATE           11.0        730000.0
# 5    ADELAIDE HILLS          BELAIR           16.0        665000.0
# 7    ADELAIDE HILLS     BRIDGEWATER           17.0        525000.0
# 27   ADELAIDE HILLS       ROSTREVOR           24.0        662500.0
# 29   ADELAIDE HILLS        STIRLING           14.0        857500.0
# ..              ...             ...            ...             ...
# 470    WEST TORRENS  NORTH PLYMPTON           12.0        562500.0
# 472    WEST TORRENS        PLYMPTON           21.0        590000.0
# 473    WEST TORRENS        RICHMOND            9.0        485000.0
# 475    WEST TORRENS    TORRENSVILLE           10.0        617500.0
# 477    WEST TORRENS      WEST BEACH           16.0        805000.0
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# 2             15.0        875000.0       0.198630      2     USA           4.0
# ...

# %%
df[(df["Sales 3Q 2020"] > 8) & (df["City"] == "ADELAIDE HILLS")]
# Out:
#               City       Suburb  Sales 3Q 2020  Median 3Q 2020  Sales 3Q 2021  \
# 2   ADELAIDE HILLS      ALDGATE           11.0        730000.0           15.0
# 5   ADELAIDE HILLS       BELAIR           16.0        665000.0           18.0
# 7   ADELAIDE HILLS  BRIDGEWATER           17.0        525000.0           13.0
# 27  ADELAIDE HILLS    ROSTREVOR           24.0        662500.0           42.0
# 29  ADELAIDE HILLS     STIRLING           14.0        857500.0            3.0
#
#     Median 3Q 2021  Median Change  Index Country  Sales Change
# 2         875000.0       0.198630      2     USA           4.0
# 5         815000.0       0.225564      5     USA           2.0
# 7         974100.0       0.855429      7     USA          -4.0
# 27        755000.0       0.139623     27     USA          18.0
# 29       1340000.0       0.562682     29     USA         -11.0

# %%
df[(df["Sales 3Q 2020"] > 20) | (df["Sales 3Q 2021"] > 20)]
# Out:
#                City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 27   ADELAIDE HILLS       ROSTREVOR           24.0        662500.0
# 55         BURNSIDE          MAGILL           38.0        670000.0
# 66     CAMPBELLTOWN      ATHELSTONE           31.0        550000.0
# 67     CAMPBELLTOWN    CAMPBELLTOWN           22.0        567500.0
# 69     CAMPBELLTOWN          MAGILL           38.0        670000.0
# ..              ...             ...            ...             ...
# 421  TEA TREE GULLY    REDWOOD PARK           29.0        422000.0
# 422  TEA TREE GULLY      RIDGEHAVEN            7.0        385000.0
# 423  TEA TREE GULLY  SALISBURY EAST           28.0        338500.0
# 428  TEA TREE GULLY     VALLEY VIEW           32.0        406000.0
# 472    WEST TORRENS        PLYMPTON           21.0        590000.0
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# 27            42.0        755000.0       0.139623     27     USA          18.0
# ...

# %%
type(df["City"]) # pandas.core.series.Series
# Out:
# pandas.core.series.Series

# %%
pd.Index([1, 2, 3])
# Out:
# Int64Index([1, 2, 3], dtype='int64')

# %%
df
# Out:
#                City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 0          ADELAIDE        ADELAIDE            3.0        671000.0
# 1          ADELAIDE  NORTH ADELAIDE            8.0       1025000.0
# 2    ADELAIDE HILLS         ALDGATE           11.0        730000.0
# 3    ADELAIDE HILLS          ASHTON            NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE            NaN             NaN
# ..              ...             ...            ...             ...
# 474    WEST TORRENS       THEBARTON            1.0        890000.0
# 475    WEST TORRENS    TORRENSVILLE           10.0        617500.0
# 476    WEST TORRENS       UNDERDALE            4.0        650000.0
# 477    WEST TORRENS      WEST BEACH           16.0        805000.0
# 478    WEST TORRENS   WEST RICHMOND            5.0        475500.0
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# 0              5.0       1012500.0       0.508942      0     USA           2.0
# ...

# %%
pd.Index([1, 2, 3])
# Out:
# Int64Index([1, 2, 3], dtype='int64')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=479, step=1)

# %%
df
# Out:
#                City          Suburb  Sales 3Q 2020  Median 3Q 2020  \
# 0          ADELAIDE        ADELAIDE            3.0        671000.0
# 1          ADELAIDE  NORTH ADELAIDE            8.0       1025000.0
# 2    ADELAIDE HILLS         ALDGATE           11.0        730000.0
# 3    ADELAIDE HILLS          ASHTON            NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE            NaN             NaN
# ..              ...             ...            ...             ...
# 474    WEST TORRENS       THEBARTON            1.0        890000.0
# 475    WEST TORRENS    TORRENSVILLE           10.0        617500.0
# 476    WEST TORRENS       UNDERDALE            4.0        650000.0
# 477    WEST TORRENS      WEST BEACH           16.0        805000.0
# 478    WEST TORRENS   WEST RICHMOND            5.0        475500.0
#
#      Sales 3Q 2021  Median 3Q 2021  Median Change  Index Country  Sales Change
# 0              5.0       1012500.0       0.508942      0     USA           2.0
# ...

# %%
df.to_csv("result.csv")

# %%
df.to_excel("result.xlsx")

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df[df.index % 2 == 1]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 7      male        group B                some college  free/reduced
# 9    female        group B                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[df.index % 2 == 0]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
count_df = pd.DataFrame()
count_df["count"] = df.groupby("race/ethnicity")["lunch"].count()
count_df
# Out:
#                 count
# race/ethnicity
# group A            89
# group B           190
# group C           319
# group D           262
# group E           140

# %%
count_df = pd.DataFrame()
count_df["count"] = df[df["math score"] > 60].groupby("race/ethnicity")["gender"].count()
count_df
# Out:
#                 count
# race/ethnicity
# group A            47
# group B           112
# group C           201
# group D           186
# group E           115

# %%
pivot = df.pivot_table(index="race/ethnicity", columns="lunch", values="math score")
pivot
# Out:
# lunch           free/reduced   standard
# race/ethnicity
# group A            55.222222  65.981132
# group B            57.434783  66.884298
# group C            56.412281  68.941463
# group D            61.115789  70.916168
# group E            66.560976  76.828283

# %%
pivot.plot()
# Out:
# <AxesSubplot:xlabel='race/ethnicity'>

# %%
pivot = df.pivot_table(index="writing score", columns="test preparation course", values="math score")
pivot.plot()
# Out:
# <AxesSubplot:xlabel='writing score'>
