# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
from selenium import webdriver
# Out:
# c:\users\jiwoo\appdata\local\programs\python\python39\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# 웹드라이브로 크롬브라우즈 띄운다.
driver_path = "chromedriver.exe"
drivers = webdriver.Chrome(executable_path=driver_path)
# Out:
# C:\Users\jiwoo\AppData\Local\Temp/ipykernel_25252/1436158339.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   drivers = webdriver.Chrome(executable_path=driver_path)

# %%
url ='https://www.google.com/search?q=cat+pictures&sxsrf=AOaemvLQo_kizdkk0dyeR3-9nMvHauXttw:1641376638519&source=lnms&tbm=isch&sa=X&ved=2ahUKEwiv1-y7rJr1AhWvHqYKHTNuB_YQ_AUoAXoECAEQAw&biw=1366&bih=625&dpr=1'

# %%
drivers.get(url)

# %%
drivers.page_source
soup = BeautifulSoup(drivers.page_source, 'html.parser')

# %%
import cv2
import urllib.request
import numpy as np
import matplotlib.pyplot as plt

def url_to_image(url):
    resp = urllib.request.urlopen(url)
    image = np.asarray(bytearray(resp.read()), dtype='uint8')
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    im_rgb= cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
    return im_rgb

# %%
plt.axis('off')
plt.imshow(url_to_image(soup.find_all('img')[2].attrs['src']))
plt.show()

# %%
plt.axis('off')
plt.figure(figsize=(25,25))

for i in range(50):
    plt.subplot(10,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(url_to_image(soup.find_all('img')[i].attrs['src']))
plt.show()
